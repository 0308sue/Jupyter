# %%
from haversine import haversine
import warnings
warnings.filterwarnings(action='ignore')
import numpy as np

# %%
import pandas as pd
df = pd.read_excel('조류_폐사체_최종가공2차-일수계산ERROR발생 재작업필요.xlsx')
df.head()
# Out:
#       발생일자(가) 축종(가) 가축전염병명(가) 광역시도(가) 시군구(가) 읍면동(가)      위도(가)       경도(가)  \
# 0  2019-01-04     닭     가금티프스    전라북도    부안군    보안면  35.631876  126.661607
# 1  2019-01-04     닭     가금티프스    전라북도    부안군    보안면  35.631876  126.661607
# 2  2019-01-04     닭     가금티프스    전라북도    부안군    보안면  35.631876  126.661607
# 3  2019-01-04     닭     가금티프스    전라북도    부안군    보안면  35.631876  126.661607
# 4  2019-01-04     닭     가금티프스    전라북도    부안군    보안면  35.631876  126.661607
#
#     시료채취일자(야) 시도(야) 시군(야)                     주소(야) 시료(야)      위도(야)  \
# 0  2021-01-01  경상남도    창원  경상남도 창원시 의창구 대산면 가술리 562   폐사체  35.315752
# 1  2021-01-08  경상남도    창원   경상남도 창원시 의창구 동읍 월잠리 318   폐사체  35.310149
# 2  2021-01-09  경상북도    구미        경상북도 구미시 지산동 812-5   폐사체  36.132744
# 3  2021-01-11   제주도    제주     제주 제주시 구좌읍 하도리 970-10    분변  33.505418
# 4  2021-01-11  경상남도    거창     경상남도 거창군 거창읍 가지리 1700   폐사체  35.694956
#
#         경도(야)      거리(KM)  발생일_시료채취일_비교  Unnamed: 17  \
# 0  128.680597  186.174759          -728        728.0
# 1  128.668833  185.254272          -728        735.0
# 2  128.355170  162.421806          -728        736.0
# 3  126.891848  237.389334          -728        738.0
# 4  127.910711  113.062449          -728        738.0
#
#                                          Unnamed: 18
# 0           "R"열에 해당하는 일수계산은 감염병발생일자 - 폐사체 발견일자 = 일수
# 1  엑셀에서는 빠른일자에서 뒤일자를 빼는 하수시그로 구현해야 에러가 없는 관계로 "-"...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
df = df.drop(['발생일_시료채취일_비교','Unnamed: 17','Unnamed: 18'],axis=1)
df.head()
# Out:
#       발생일자(가) 축종(가) 가축전염병명(가) 광역시도(가) 시군구(가) 읍면동(가)      위도(가)       경도(가)  \
# 0  2019-01-04     닭     가금티프스    전라북도    부안군    보안면  35.631876  126.661607
# 1  2019-01-04     닭     가금티프스    전라북도    부안군    보안면  35.631876  126.661607
# 2  2019-01-04     닭     가금티프스    전라북도    부안군    보안면  35.631876  126.661607
# 3  2019-01-04     닭     가금티프스    전라북도    부안군    보안면  35.631876  126.661607
# 4  2019-01-04     닭     가금티프스    전라북도    부안군    보안면  35.631876  126.661607
#
#     시료채취일자(야) 시도(야) 시군(야)                     주소(야) 시료(야)      위도(야)  \
# 0  2021-01-01  경상남도    창원  경상남도 창원시 의창구 대산면 가술리 562   폐사체  35.315752
# 1  2021-01-08  경상남도    창원   경상남도 창원시 의창구 동읍 월잠리 318   폐사체  35.310149
# 2  2021-01-09  경상북도    구미        경상북도 구미시 지산동 812-5   폐사체  36.132744
# 3  2021-01-11   제주도    제주     제주 제주시 구좌읍 하도리 970-10    분변  33.505418
# 4  2021-01-11  경상남도    거창     경상남도 거창군 거창읍 가지리 1700   폐사체  35.694956
#
#         경도(야)      거리(KM)
# 0  128.680597  186.174759
# 1  128.668833  185.254272
# 2  128.355170  162.421806
# 3  126.891848  237.389334
# 4  127.910711  113.062449

# %%
happen = df['발생일자(가)']
collect = df['시료채취일자(야)']
# happen.loc[0]
# print(type(collect.loc[0]))
collects = collect.loc[11]
print(collects)
# Out:
# 2021-01-13

# %%
from datetime import datetime
date_diff_list = []

for h in range(len(happen)):
    happenr = happen.loc[h]
    collectr = collect.loc[h]
    
    happend = datetime.strptime(happenr, "%Y-%m-%d")
    collectd = datetime.strptime(collectr, "%Y-%m-%d")
    
    date_diff = collectd - happend
    date_diff_list.append(date_diff)

df['시료채취일_발생일_비교'] = date_diff_list
df
# Out:
#           발생일자(가) 축종(가) 가축전염병명(가) 광역시도(가) 시군구(가) 읍면동(가)      위도(가)  \
# 0      2019-01-04     닭     가금티프스    전라북도    부안군    보안면  35.631876
# 1      2019-01-04     닭     가금티프스    전라북도    부안군    보안면  35.631876
# 2      2019-01-04     닭     가금티프스    전라북도    부안군    보안면  35.631876
# 3      2019-01-04     닭     가금티프스    전라북도    부안군    보안면  35.631876
# 4      2019-01-04     닭     가금티프스    전라북도    부안군    보안면  35.631876
# ...           ...   ...       ...     ...    ...    ...        ...
# 36295  2021-12-29     닭     가금티프스     경기도    양평군    양동면  37.412233
# 36296  2021-12-29     닭     가금티프스     경기도    양평군    양동면  37.412233
# 36297  2021-12-29     닭     가금티프스     경기도    양평군    양동면  37.412233
# 36298  2021-12-29     닭     가금티프스     경기도    양평군    양동면  37.412233
# 36299  2021-12-29     닭     가금티프스     경기도    양평군    양동면  37.412233
#
#             경도(가)   시료채취일자(야) 시도(야) 시군(야)                     주소(야) 시료(야)  \
# 0      126.661607  2021-01-01  경상남도    창원  경상남도 창원시 의창구 대산면 가술리 562   폐사체
# 1      126.661607  2021-01-08  경상남도    창원   경상남도 창원시 의창구 동읍 월잠리 318   폐사체
# 2      126.661607  2021-01-09  경상북도    구미        경상북도 구미시 지산동 812-5   폐사체
# 3      126.661607  2021-01-11   제주도    제주     제주 제주시 구좌읍 하도리 970-10    분변
# 4      126.661607  2021-01-11  경상남도    거창     경상남도 거창군 거창읍 가지리 1700   폐사체
# ...           ...         ...   ...   ...                       ...   ...
# 36295  127.748239  2022-03-15   경기도   고양시          경기도 고양시 일산동구 장항동   폐사체
# 36296  127.748239  2022-03-18   경기도   고양시          경기도 고양시 일산동구 장항동   폐사체
# 36297  127.748239  2022-03-22   강원도   고성군           강원도 고성군 죽왕면 오봉리   폐사체
# 36298  127.748239  2022-03-23   강원도   고성군           강원도 고성군 죽왕면 오봉리   폐사체
# 36299  127.748239  2022-03-24   강원도   고성군           강원도 고성군 죽왕면 오봉리   폐사체
#
#            위도(야)       경도(야)      거리(KM) 시료채취일_발생일_비교
# 0      35.315752  128.680597  186.174759     728 days
# 1      35.310149  128.668833  185.254272     735 days
# 2      36.132744  128.355170  162.421806     736 days
# 3      33.505418  126.891848  237.389334     738 days
# 4      35.694956  127.910711  113.062449     738 days
# ...          ...         ...         ...          ...
# 36295  37.641725  126.770233   89.941012      76 days
# 36296  37.641725  126.770233   89.941012      79 days
# 36297  38.341111  128.499584  122.542459      83 days
# 36298  38.341111  128.499584  122.542459      84 days
# 36299  38.341111  128.499584  122.542459      85 days
#
# [36300 rows x 17 columns]

# %%
df.to_excel('조류_폐사체_최종가공2차.xlsx')
